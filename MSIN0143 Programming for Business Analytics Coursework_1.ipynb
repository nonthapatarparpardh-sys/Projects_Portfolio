# %% [markdown]
# # MSIN0143: Programming for Business Analytics

# %% [markdown]
# # Exploratory Analysis on factors that influence Singaporean property prices

# %% [markdown]
# Group members: ____

# %% [markdown]
# ## Table of Content:
# * [Section 1: Introduction](#first-bullet)
# * [Section 2: Data Preparation](#second-bullet)
#   * [2.1: Data Description](#2.1-bullet)
#   * [2.2: Data Preparation](#2.2-bullet)
# * [Section 3: Data Cleaning](#third-bullet)
# * [Section 4: Data Analysis](#fourth-bullet)
#   * [4.1: Distribution of Resale Prices](#4.1-bullet)
#   * [4.2: Mean Resale Price by Town](#4.2-bullet)
#   * [4.3: Number of Stations within 604 meters Radius and Resale Prices](#4.3-bullet)
#   * [4.4: Number of Supermarkets within 603 meters Radius and Resale Prices](#4.4-bullet)
#   * [4.5: Resale Prices factors](#4.5-bullet)
#     * [4.5.1: Floor Area](#4.5.1-bullet)
#     * [4.5.2: Flat Type](#4.5.2-bullet)
#     * [4.5.3: Remaining Lease](#4.5.3-bullet)
#     * [4.5.4: Distance to Nearest MRT](#4.5.4-bullet)
#   * [4.6: Resale Price Distribution by Flat Model](#4.5.5-bullet)
#
# * [Section 5: Prediction Models](#fifth-bullet)
#   * [5.1: Linear Regression](#5.1-bullet)
#   * [5.2: Decision Tree Model](#5.2-bullet)
# * [Section 6: Challenges and Limitations](#sixth-bullet)
# * [Section 7: References](#seventh-bullet)
# * [Section 8: Appendices](#eighth-bullet)

# %% [markdown]
# # Section 1: Introduction <a class="anchor" id="first-bullet"></a>

# %% [markdown]
# # Section 2: Data Preparation <a class="anchor" id="second-bullet"></a>

# %%
import csv
import numpy
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 2.1 Data Description <a class="anchor" id="2.1-bullet"></a>

# %% [markdown]
# This report utilises 3 main datasets for it's research, collected from a combination of open data provided by the Singaporean Government, and through a third party source on GitHub. The first dataset contained information regarding the resale prices and descriptions of properties sold in Singapore, collected from 2017 onwards until the end of 2023. The second dataset contained information on registered supermarkets and their locations, and the last dataset contained information on every public transport train station and their relevant location.

# %% [markdown]
# ## 2.2 Data Preparation <a class="anchor" id="2.2-bullet"></a>

# %% [markdown]
# To explore the factors and its influence on Singaporean property prices, we combined the 3 datasets into 1 single file

# %%
# Path to the CSV file
file_path = '/Users/nonthapatarparpardh/Downloads/full_combined_address_mrt_supermarkets.xlsx'

# Read the CSV file with a different encoding
data = pd.read_excel(file_path)
pd.set_option('display.max_columns', None) 
data
# Out:
#           month        town         flat_type block        street_name  \
# 0       2017-01  ANG MO KIO            2 ROOM   406  ANG MO KIO AVE 10
# 1       2017-01  ANG MO KIO            3 ROOM   108   ANG MO KIO AVE 4
# 2       2017-01  ANG MO KIO            3 ROOM   602   ANG MO KIO AVE 5
# 3       2017-01  ANG MO KIO            3 ROOM   465  ANG MO KIO AVE 10
# 4       2017-01  ANG MO KIO            3 ROOM   601   ANG MO KIO AVE 5
# ...         ...         ...               ...   ...                ...
# 166683  2023-05      YISHUN         EXECUTIVE   827       YISHUN ST 81
# 166684  2023-05      YISHUN         EXECUTIVE   824       YISHUN ST 81
# 166685  2023-07      YISHUN         EXECUTIVE   837       YISHUN ST 81
# 166686  2023-01      YISHUN  MULTI-GENERATION   666       YISHUN AVE 4
# 166687  2023-06      YISHUN  MULTI-GENERATION   633       YISHUN ST 61
#
#        storey_range  floor_area_sqm        flat_model  lease_commence_date  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 166688 entries, 0 to 166687
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   month                     166688 non-null  object
#  1   town                      166688 non-null  object
#  2   flat_type                 166688 non-null  object
#  3   block                     166688 non-null  object
#  4   street_name               166688 non-null  object
#  5   storey_range              166688 non-null  object
#  6   floor_area_sqm            166688 non-null  float64
#  7   flat_model                166688 non-null  object
#  8   lease_commence_date       166688 non-null  int64
#  9   remaining_lease           166688 non-null  object
#  10  full address              166688 non-null  object
#  11  POSTAL                    166626 non-null  object
#  12  LATITUDE                  166626 non-null  float64
# ...
